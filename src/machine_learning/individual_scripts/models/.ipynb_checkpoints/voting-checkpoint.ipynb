# %%
import pandas as pd
import numpy as np
import os
from data_load_functions import path_from_inputs, split_from_path # this is user-defined in a .py file
from sklearn.metrics import accuracy_score, mean_absolute_error, mean_squared_error, r2_score, \
    roc_curve, auc, precision_score, recall_score, confusion_matrix, precision_recall_curve
import math
import statistics
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import LinearSVC, SVC
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, VotingClassifier
from catboost import CatBoostClassifier
import time

# %%
## INPUTS SPECIFIED BY USER ##
splits = 10 # as an int, number of folds
if splits >= 5 and splits <= 10:
    split_dir = f'{splits}_fold'
else:
    split_dir = 'loocv'
lin_log2 = 'linear' # linear or log2

# %%
# retrieve paths for specified number of splits and type of data
path_list = path_from_inputs(splits, lin_log2, 'L1')

# %%
classifiers = {
    "logistic": LogisticRegression(),
    "lin_svc": LinearSVC(random_state=seed, dual="auto"),
    "svc": SVC(random_state=seed),
    "sgd_logistic": SGDClassifier(random_state=seed, loss="log_loss"),
    "rf": RandomForestClassifier(random_state=seed),
    "ada": AdaBoostClassifier(random_state=seed, algorithm='SAMME'),
    "xgb": xgb.XGBClassifier(objective='binary:logistic', random_state=seed, use_label_encoder=False),
    "cat": CatBoostClassifier(random_state=seed, verbose=0),
    "vote_hard": VotingClassifier(estimators=[("svc", SVC(random_state=seed)), ("logistic", LogisticRegression()), ("rf", RandomForestClassifier(random_state=seed))], voting='hard'),
        "vote_soft": VotingClassifier(estimators=[("svc", SVC(random_state=seed, probability=True)), ("logistic", LogisticRegression()), ("rf", RandomForestClassifier(random_state=seed))], voting='soft')}

# %%
# initialize lists for metrics
acc_list = []
auc_list = []
prec_list = []
tpr_list = []
fpr_list = []
selected_feats_list = []
seed = 2
model_name = VotingClassifier(estimators=[("svc", classifiers["svc"]), ("logistic", classifiers["logistic"]), ("rf", classifiers["rf"])],#,
                                          #("nn",  MLPClassifier(hidden_layer_sizes=(3, 5), random_state=seed, max_iter=1000, solver='lbfgs', alpha=0.000001))]
                              voting='hard')

for i in range(1, splits + 1):
    X_train, X_test, y_train, y_test = split_from_path(path_list[i-1], drop_cols='mtx_binary') # using lasso rn
    model = model_name
    model.fit(X_train, y_train)
    # predict on test
    y_pred = model.predict(X_test)
    # try:
    #     y_pred_proba = model.predict_proba(X_test)[:, 1]
    # except AttributeError:
    #     try:
    #         y_pred_proba = model.decision_function(X_test)
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        try:
            fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
            #roc_auc = auc(fprs, tprs)
        except ValueError:
            roc_auc = None
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
        if (tn + fn) != 0:
            npv = tn / (tn + fn)
        else:
             npv = None
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
   # auc_list.append(roc_auc)
    acc_list.append(acc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Report avg metrics
#print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# Mean Accuracy:  0.7
# Mean Precision:  0.6900000000000001
# Mean Recall (TPR):  1.0
# Mean FPR:  0.75

# %%
# soft vote
# initialize lists for metrics
acc_list = []
auc_list = []
prec_list = []
tpr_list = []
fpr_list = []
selected_feats_list = []
seed = 42
model_name = VotingClassifier(estimators=[("svc", SVC(random_state=seed, probability=True)),
                                          ("logistic", LogisticRegression()),
                                           ("rf", RandomForestClassifier(random_state=seed)),
                                           ("nn",  MLPClassifier(hidden_layer_sizes=(3, 5),
                                                                 random_state=seed, max_iter=1000,
                                                                 solver='lbfgs', alpha=0.000001))
                                         ],voting='soft')

for i in range(1, splits + 1):
    X_train, X_test, y_train, y_test = split_from_path(path_list[i-1], drop_cols='mtx_binary') # using lasso rn
    model = model_name
    model.fit(X_train, y_train)
    # predict on test
    y_pred = model.predict(X_test)
    try:
        y_pred_proba = model.predict_proba(X_test)[:, 1]
    except AttributeError:
         y_pred_proba = model.decision_function(X_test)
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        try:
            fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
            roc_auc = auc(fprs, tprs)
        except ValueError:
            roc_auc = None
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
        if (tn + fn) != 0:
            npv = tn / (tn + fn)
        else:
             npv = None
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
    auc_list.append(roc_auc)
    acc_list.append(acc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)
    print(f"Split {i} - AUC: {roc_auc}, Accuracy: {acc}, Precision: {prec}, TPR: {tpr}, FPR: {fpr}")

# Report avg metrics
print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# Split 1 - AUC: 0.7777777777777779, Accuracy: 0.5, Precision: 0.5, TPR: 1.0, FPR: 1.0
# Split 2 - AUC: 0.7777777777777778, Accuracy: 0.5, Precision: 0.5, TPR: 1.0, FPR: 1.0
# Split 3 - AUC: 0.7777777777777779, Accuracy: 0.5, Precision: 0.5, TPR: 1.0, FPR: 1.0
# Split 4 - AUC: 0.375, Accuracy: 0.5, Precision: 0.6, TPR: 0.75, FPR: 1.0
# Split 5 - AUC: 0.875, Accuracy: 0.6666666666666666, Precision: 0.75, TPR: 0.75, FPR: 0.5
# Split 6 - AUC: 1.0, Accuracy: 0.8333333333333334, Precision: 1.0, TPR: 0.75, FPR: 0.0
# Split 7 - AUC: 0.875, Accuracy: 0.8333333333333334, Precision: 1.0, TPR: 0.75, FPR: 0.0
# Split 8 - AUC: 0.875, Accuracy: 0.8333333333333334, Precision: 1.0, TPR: 0.75, FPR: 0.0
# Split 9 - AUC: 1.0, Accuracy: 1.0, Precision: 1.0, TPR: 1.0, FPR: 0.0
# Split 10 - AUC: 0.5, Accuracy: 0.6666666666666666, Precision: 0.6666666666666666, TPR: 1.0, FPR: 1.0
# Mean AUC:  0.7833333333333334
# Mean Accuracy:  0.6833333333333333
# Mean Precision:  0.7516666666666667
# Mean Recall (TPR):  0.875
# Mean FPR:  0.55

# %%
#### try knn
from sklearn.neighbors import KNeighborsClassifier
# initialize lists for metrics
acc_list = []
auc_list = []
prec_list = []
tpr_list = []
fpr_list = []
selected_feats_list = []
seed = 2
model_name = KNeighborsClassifier(n_neighbors=2, weights='distance')

for i in range(1, splits + 1):
    X_train, X_test, y_train, y_test = split_from_path(path_list[i-1], drop_cols='mtx_binary') # using lasso rn
    model = model_name
    model.fit(X_train, y_train)
    # predict on test
    y_pred = model.predict(X_test)
    # try:
    #     y_pred_proba = model.predict_proba(X_test)[:, 1]
    # except AttributeError:
    #     try:
    #         y_pred_proba = model.decision_function(X_test)
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        try:
            fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
            #roc_auc = auc(fprs, tprs)
        except ValueError:
            roc_auc = None
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
        if (tn + fn) != 0:
            npv = tn / (tn + fn)
        else:
             npv = None
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
   # auc_list.append(roc_auc)
    acc_list.append(acc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Report avg metrics
#print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# Mean Accuracy:  0.6833333333333333
# Mean Precision:  0.7283333333333333
# Mean Recall (TPR):  0.8083333333333332
# Mean FPR:  0.5333333333333333

# %%
# try ann
from sklearn.neural_network import MLPClassifier
# initialize lists for metrics
acc_list = []
auc_list = []
prec_list = []
tpr_list = []
fpr_list = []
selected_feats_list = []

model_name = MLPClassifier(hidden_layer_sizes=(3,5), random_state=42, max_iter=1000, solver='lbfgs', alpha=0.000001)
# solver should be lbfgs since the data size is small (from documentation)

for i in range(1, splits + 1):
    X_train, X_test, y_train, y_test = split_from_path(path_list[i-1], drop_cols='mtx_binary') # using lasso rn
    model = model_name
    model.fit(X_train, y_train)
    # predict on test
    y_pred = model.predict(X_test)
    # try:
    #     y_pred_proba = model.predict_proba(X_test)[:, 1]
    # except AttributeError:
    #     try:
    #         y_pred_proba = model.decision_function(X_test)
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        try:
            fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
            #roc_auc = auc(fprs, tprs)
        except ValueError:
            roc_auc = None
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
        if (tn + fn) != 0:
            npv = tn / (tn + fn)
        else:
             npv = None
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
   # auc_list.append(roc_auc)
    acc_list.append(acc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)

# Report avg metrics
#print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# Mean Accuracy:  0.7166666666666667
# Mean Precision:  0.8116666666666668
# Mean Recall (TPR):  0.7916666666666666
# Mean FPR:  0.36666666666666664

# %%
# initialize lists for metrics
acc_list = []
auc_list = []
prec_list = []
tpr_list = []
fpr_list = []
selected_feats_list = []
threshold = 0.005 # from visualization
seed = 3

# Perform on the folds
for i in range(1, splits + 1):
    
    X_train, X_test, y_train, y_test = split_from_path(path_list[i-1], drop_cols='mtx_binary')
    # A list of possible C values (lambda), and this finds the optimal lambda
    Cs = np.logspace(-3, 0)
    # L2 penalty makes it ridge
    model_cv = LogisticRegressionCV(Cs=Cs, cv=10, penalty='l2', solver='liblinear', random_state=seed)
    model_cv.fit(X_train, y_train)
    # Uses the best lambda now
    best_lambda = model_cv.C_[0]
    # Using the developed ridge model to predict on test data
    model = LogisticRegression(penalty='l2', C=best_lambda, solver='liblinear', random_state=seed)
    model.fit(X_train, y_train)
    
    # # Get the coefficients and zero out those below the threshold
    coefficients = model.coef_
    coefficients[np.abs(coefficients) < threshold] = 0
    
    # # Assign the modified coefficients back to the model
    model.coef_ = coefficients
    
    # Predict probabilities on test data
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred = model.predict(X_test)
    # Identify non-zero coefficients
    non_zero_coefs = model.coef_[0] != 0
    selected_features = X_train.columns[non_zero_coefs]
    # Subset the original DataFrame to include only the selected features
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]
    
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
        roc_auc = auc(fprs, tprs)
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
    
        try:
            negative_predictive_value = tn / (tn + fn)
        except ZeroDivisionError:
            negative_predictive_value = "nan"
        
        try:
            num = (tn * tp) - (fn * fp)
            denom = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
            denom = math.sqrt(denom)
            matthews_corr_coef = num / denom
        except ZeroDivisionError:
            matthews_corr_coef = "nan"
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
    # append metrics for averages
    acc_list.append(acc)
    auc_list.append(roc_auc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)
    selected_feats_list.append(list(selected_features))
    # Combine subsets X_train and y_train for saving to CSV
    train_selected = pd.concat([X_train_selected, y_train], axis=1)
    test_selected = pd.concat([X_test_selected, y_test], axis=1)
    train_selected.to_csv(os.path.join(output_dir, f'train_{i}.csv'), index=False)
    test_selected.to_csv(os.path.join(output_dir, f'test_{i}.csv'), index=False)
    
    print(f"Split {i} - AUC: {roc_auc}, Accuracy: {acc}, Precision: {prec}, TPR: {tpr}, FPR: {fpr}")

# Report avg metrics
print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# Split 1 - AUC: 0.4444444444444445, Accuracy: 0.3333333333333333, Precision: 0.4, TPR: 0.6666666666666666, FPR: 1.0
# Split 2 - AUC: 0.6666666666666667, Accuracy: 0.5, Precision: 0.5, TPR: 1.0, FPR: 1.0
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:57: RuntimeWarning: invalid value encountered in scalar divide
#   negative_predictive_value = tn / (tn + fn)
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:65: RuntimeWarning: invalid value encountered in divide
#   matthews_corr_coef = num / denom
# Split 3 - AUC: 1.0, Accuracy: 0.6666666666666666, Precision: 0.6, TPR: 1.0, FPR: 0.6666666666666666
# Split 4 - AUC: 0.625, Accuracy: 0.6666666666666666, Precision: 0.6666666666666666, TPR: 1.0, FPR: 1.0
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:57: RuntimeWarning: invalid value encountered in scalar divide
#   negative_predictive_value = tn / (tn + fn)
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:65: RuntimeWarning: invalid value encountered in divide
#   matthews_corr_coef = num / denom
# Split 5 - AUC: 0.625, Accuracy: 0.6666666666666666, Precision: 0.75, TPR: 0.75, FPR: 0.5
# Split 6 - AUC: 1.0, Accuracy: 0.6666666666666666, Precision: 1.0, TPR: 0.5, FPR: 0.0
# Split 7 - AUC: 0.75, Accuracy: 0.8333333333333334, Precision: 1.0, TPR: 0.75, FPR: 0.0
# Split 8 - AUC: 0.875, Accuracy: 0.6666666666666666, Precision: 1.0, TPR: 0.5, FPR: 0.0
# Split 9 - AUC: 1.0, Accuracy: 1.0, Precision: 1.0, TPR: 1.0, FPR: 0.0
# Split 10 - AUC: 0.5, Accuracy: 0.6666666666666666, Precision: 0.6666666666666666, TPR: 1.0, FPR: 1.0
# Mean AUC:  0.7486111111111111
# Mean Accuracy:  0.6666666666666667
# Mean Precision:  0.7583333333333333
# Mean Recall (TPR):  0.8166666666666667
# Mean FPR:  0.5166666666666666
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:57: RuntimeWarning: invalid value encountered in scalar divide
#   negative_predictive_value = tn / (tn + fn)
# /var/folders/dl/5lw3wzn54kg220nzcdqxsvt00000gr/T/ipykernel_6955/3374810313.py:65: RuntimeWarning: invalid value encountered in divide
#   matthews_corr_coef = num / denom

# %%
# Perform on the folds
splits = 10

path_list2 = path_from_inputs(splits, lin_log2)
for i in range(1, splits + 1):
    X_train, X_test, y_train, y_test = split_from_path(path_list2[i-1])
    # A list of possible C values (lambda), and this finds the optimal lambda
    Cs = np.logspace(-3, 0)
    # L2 penalty makes it ridge
    model_cv = LogisticRegressionCV(Cs=Cs, cv=10, penalty='l2', solver='liblinear', random_state=seed)
    model_cv.fit(X_train, y_train)
    # Uses the best lambda now
    best_lambda = model_cv.C_[0]
    # Using the developed ridge model to predict on test data
    model = LogisticRegression(penalty='l2', C=best_lambda, solver='liblinear', random_state=seed)
    model.fit(X_train, y_train)
    
    # Get the coefficients and zero out those below the threshold
 #   coefficients = model.coef_
  #  coefficients[np.abs(coefficients) < threshold] = 0
    
  #  # Assign the modified coefficients back to the model
    #model.coef_ = coefficients
    
    # Predict probabilities on test data
    y_pred_proba = model.predict_proba(X_test)[:, 1]
    y_pred = model.predict(X_test)
    # Identify non-zero coefficients
    non_zero_coefs = model.coef_[0] != 0
    selected_features = X_train.columns[non_zero_coefs]
    # Subset the original DataFrame to include only the selected features
    X_train_selected = X_train[selected_features]
    X_test_selected = X_test[selected_features]
    
    # calculate metrics
    # not all of these are getting reported in this case for feature selection, but I wanted to have my version of this code implemented in a model
    try: # this code is adapted from hurben RA_ACPA_multiomics/src/machine_learning/classification_5fold.2class.opti.withMCC.py
        tn, fp, fn, tp = confusion_matrix(y_test, y_pred, labels=[0, 1]).ravel()
        fprs, tprs, thresholds = roc_curve(y_test, y_pred_proba)
        roc_auc = auc(fprs, tprs)
        acc = (tp + tn) / (tp + fp + tn + fn)
        prec = tp / (tp + fp)
        tpr = tp / (tp + fn)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        fnr = fn / (fn + tp)
    
        try:
            negative_predictive_value = tn / (tn + fn)
        except ZeroDivisionError:
            negative_predictive_value = "nan"
        
        try:
            num = (tn * tp) - (fn * fp)
            denom = (tp + fp) * (tp + fn) * (tn + fp) * (tn + fn)
            denom = math.sqrt(denom)
            matthews_corr_coef = num / denom
        except ZeroDivisionError:
            matthews_corr_coef = "nan"
    except ZeroDivisionError:
        print("Error ACC: %s %s %s %s %s" % (tp, tn, fp, tn, fn))
    # append metrics for averages
    acc_list.append(acc)
    auc_list.append(roc_auc)
    prec_list.append(prec)
    tpr_list.append(tpr)
    fpr_list.append(fpr)
    # selected_feats_list.append(list(selected_features))
    # Combine subsets X_train and y_train for saving to CSV
    # train_selected = pd.concat([X_train_selected, y_train], axis=1)
    # test_selected = pd.concat([X_test_selected, y_test], axis=1)
    # train_selected.to_csv(os.path.join(output_dir, f'train_{i}.csv'), index=False)
    # test_selected.to_csv(os.path.join(output_dir, f'test_{i}.csv'), index=False)
    
    print(f"Split {i} - AUC: {roc_auc}, Accuracy: {acc}, Precision: {prec}, TPR: {tpr}, FPR: {fpr}")

# Report avg metrics
print("Mean AUC: ", np.mean(auc_list))
print("Mean Accuracy: ", np.mean(acc_list))
print("Mean Precision: ", np.mean(prec_list))
print("Mean Recall (TPR): ", np.mean(tpr_list))
print("Mean FPR: ", np.mean(fpr_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 9
#       7 Cs = np.logspace(-3, 0)
#       8 # L2 penalty makes it ridge
# ----> 9 model_cv = LogisticRegressionCV(Cs=Cs, cv=10, penalty='l2', solver='liblinear', random_state=seed)
#      10 model_cv.fit(X_train, y_train)
#      11 # Uses the best lambda now
#
# NameError: name 'seed' is not defined

# %%
coefficients = model.coef_[0]  # Assuming binary classification, otherwise adjust accordingly
feature_names = X_train.columns if hasattr(X_train, 'columns') else [f'feature_{i}' for i in range(X_train.shape[1])]

# Create a DataFrame
coeff_df = pd.DataFrame({'Feature': feature_names, 'Coefficient': coefficients})

# Display the DataFrame
print(coeff_df)
# Out:
#                                      Feature  Coefficient
# 0         linear_UniProtA0FGR8#ESYT2OID31134     0.000759
# 1          linear_UniProtA1E959#ODAMOID20793    -0.000007
# 2         linear_UniProtA1KZ92#PXDNLOID31405     0.000913
# 3         linear_UniProtA1L4H1#SSC5DOID20351     0.000020
# 4          linear_UniProtA4D1B5#GSAPOID21173     0.008054
# ...                                      ...          ...
# 2899      linear_UniProtQ9Y6N7#ROBO1OID20734     0.000044
# 2900  linear_UniProtQ9Y6Q6#TNFRSF11AOID20646    -0.000234
# 2901       linear_UniProtQ9Y6U3#SCINOID30857     0.000488
# 2902       linear_UniProtQ9Y6X8#ZHX2OID31140    -0.000191
# 2903       linear_UniProtQ9Y6Y9#LY96OID20945    -0.000122
#
# [2904 rows x 2 columns]

# %%
coeff_df.loc[np.abs(coeff_df['Coefficient']) > 0.005]
# Out:
#                                     Feature  Coefficient
# 4         linear_UniProtA4D1B5#GSAPOID21173     0.008054
# 10       linear_UniProtA6NGG8#PCAREOID30838    -0.006913
# 18    linear_UniProtA8MVW0#FAM171A2OID31005     0.013105
# 60       linear_UniProtO00534#VWA5AOID31198     0.009712
# 63       linear_UniProtO00567#NOP56OID30055    -0.005515
# ...                                     ...          ...
# 2668      linear_UniProtQ9NWU2#GID8OID31041    -0.007891
# 2808      linear_UniProtQ9UMX5#NENFOID31354     0.006605
# 2814      linear_UniProtQ9UNP9#PPIEOID31279    -0.012616
# 2821    linear_UniProtQ9UPY8#MAPRE3OID31177     0.005906
# 2846    linear_UniProtQ9Y2W1#THRAP3OID30053    -0.005425
#
# [85 rows x 2 columns]

# %%
plt.figure(figsize=(10, 5))
plt.hist(coeff_df['Coefficient'], bins=30, edgecolor='k')
plt.title('Distribution of Ridge Coefficients')
plt.xlabel('Coefficient Value')
plt.ylabel('Frequency')
plt.show()

# %%
# unpack the list of all the selected features
flat_feat_sel_list = [
    x
    for xs in selected_feats_list
    for x in xs
]

feat_dict = {x:0 for x in flat_feat_sel_list}
for x in flat_feat_sel_list:
    feat_dict[x] += 1

# %%
feat_dict
# Out:
# {'linear_UniProtA4D1B5#GSAPOID21173': 4,
#  'linear_UniProtA8MVW0#FAM171A2OID31005': 4,
#  'linear_UniProtO00534#VWA5AOID31198': 4,
#  'linear_UniProtO43320#FGF16OID30535': 4,
#  'linear_UniProtO43422#THAP12OID31238': 4,
#  'linear_UniProtO75121#MFAP3LOID30933': 4,
#  'linear_UniProtO75312#ZPR1OID30801': 4,
#  'linear_UniProtO95670#ATP6V1G2OID30167': 4,
#  'linear_UniProtP01242#GH2OID21168': 4,
#  'linear_UniProtP04090#RLN2OID30601': 4,
#  'linear_UniProtP04234#CD3DOID30827': 4,
#  'linear_UniProtP04808#RLN1OID30995': 4,
#  'linear_UniProtP05112#IL4OID20426': 5,
#  'linear_UniProtP05113#IL5OID20472': 4,
#  'linear_UniProtP11310#ACADMOID31277': 3,
#  'linear_UniProtP14649#MYL6BOID30936': 4,
#  'linear_UniProtP21817#RYR1OID30085': 3,
#  'linear_UniProtP43632#KIR2DS4OID31432': 4,
#  'linear_UniProtP48436#SOX9OID30905': 4,
#  'linear_UniProtP49223#SPINT3OID31509': 5,
#  'linear_UniProtP49662#CASP4OID31276': 4,
#  'linear_UniProtP51460#INSL3OID31129': 3,
#  'linear_UniProtP51511#MMP15OID30299': 4,
#  'linear_UniProtP80098#CCL7OID20523': 4,
#  'linear_UniProtQ14894#CRYMOID30815': 1,
#  'linear_UniProtQ15102#PAFAH1B3OID30998': 4,
#  'linear_UniProtQ3B7J2#GFOD2OID21216': 5,
#  'linear_UniProtQ5SXM8#DNLZOID30822': 4,
#  'linear_UniProtQ6PH85#DCUN1D2OID31231': 4,
#  'linear_UniProtQ6ZMH5#SLC39A5OID20539': 3,
#  'linear_UniProtQ86SQ0#PHLDB2OID31167': 5,
#  'linear_UniProtQ8IW75#SERPINA12OID20219': 4,
#  'linear_UniProtQ8IYS2#KIAA2013OID31392': 4,
#  'linear_UniProtQ8N907#DAND5OID30420': 2,
#  'linear_UniProtQ8WTQ1#DEFB104A_DEFB104BOID30849': 5,
#  'linear_UniProtQ8WXG9#ADGRV1OID30877': 2,
#  'linear_UniProtQ93062#RBPMSOID30507': 3,
#  'linear_UniProtQ96L15#ART5OID30828': 4,
#  'linear_UniProtQ99731#CCL19OID21030': 3,
#  'linear_UniProtQ9NQW8#CNGB3OID30805': 4,
#  'linear_UniProtQ9NRD8#DUOX2OID20059': 1,
#  'linear_UniProtQ9UNP9#PPIEOID31279': 2,
#  'linear_UniProtQ9Y3B9#RRP15OID30867': 3,
#  'linear_UniProtO95256#IL18RAPOID20900': 1,
#  'linear_UniProtO95760#IL33OID20428': 1,
#  'linear_UniProtP01241#GH1OID20220': 3,
#  'linear_UniProtP05787#KRT8OID30865': 4,
#  'linear_UniProtP07288#KLK3OID30364': 2,
#  'linear_UniProtP10109#FDX1OID30078': 2,
#  'linear_UniProtP13236#CCL4OID20695': 1,
#  'linear_UniProtP20382#PMCHOID30172': 4,
#  'linear_UniProtP20809#IL11OID20455': 1,
#  'linear_UniProtP23435#CBLN1OID30851': 1,
#  'linear_UniProtP25092#GUCY2COID31318': 4,
#  'linear_UniProtP29353#SHC1OID31222': 3,
#  'linear_UniProtP30047#GCHFROID30631': 2,
#  'linear_UniProtP34910#EVI2BOID31227': 3,
#  'linear_UniProtP47992#XCL1OID21398': 4,
#  'linear_UniProtP78556#CCL20OID20671': 1,
#  'linear_UniProtQ01581#HMGCS1OID30157': 2,
#  'linear_UniProtQ16520#BATFOID30896': 3,
#  'linear_UniProtQ8N556#AFAP1OID30569': 2,
#  'linear_UniProtQ8NET8#TRPV3OID30128': 4,
#  'linear_UniProtQ93052#LPPOID30190': 4,
#  'linear_UniProtQ9GZP4#PITHD1OID31215': 4,
#  'linear_UniProtQ9Y2W1#THRAP3OID30053': 2,
#  'linear_UniProtP05187#ALPPOID21383': 1,
#  'linear_UniProtP13385#TDGF1OID20816': 2,
#  'linear_UniProtQ6N021#TET2OID31266': 3,
#  'linear_UniProtP43007#SLC1A4OID30926': 1,
#  'linear_UniProtP10636#MAPTOID20830': 1,
#  'linear_UniProtP15509#CSF2RAOID20915': 1,
#  'linear_UniProtP30304#CDC25AOID31189': 1,
#  'linear_UniProtQ6EBC2#IL31OID30487': 1,
#  'linear_UniProtQ8IZJ0#IFNL2OID30791': 1,
#  'linear_UniProtQ96IW2#SHDOID30098': 1,
#  'linear_UniProtQ96PD4#IL17FOID20456': 1}

# %%
X_train_selected_list = []
lasso_paths = path_from_inputs(splits, lin_log2, 'L1')
for i in range(splits):
    X_train_selected, X_test, y_train, y_test = split_from_path(lasso_paths[i], drop_cols=[])
    X_train_selected_list.append(X_train_selected)

# Dictionary to store the number of splits each feature is missing from
missing_splits_dict = {feature: [] for feature in feat_dict.keys()}

# Update the occurrence and missing splits for each feature
for i, X_train_selected in enumerate(X_train_selected_list):
    current_features = X_train_selected.columns
    for feature in feat_dict.keys():
        if feature not in current_features:
            missing_splits_dict[feature].append(f'Split {i+1}')

# Create a dataframe to store the result
results = []
for feature, num_occurrences in feat_dict.items():
    missing_splits = missing_splits_dict[feature]
    if not missing_splits:
        missing_splits = 'None'
    else:
        missing_splits = ', '.join(missing_splits)
    results.append([feature, num_occurrences, missing_splits])

results_df = pd.DataFrame(results, columns=['Feature', 'Num_Occurrences', 'Missing_Splits'])
results_df = results_df.sort_values(by='Num_Occurrences', ascending=False)

results_df.to_csv(os.path.join(output_dir, 'feature_occurrences.csv'), index=False)
results_df
# Out:
#                                            Feature  Num_Occurrences  \
# 19             linear_UniProtP49223#SPINT3OID31509                5
# 30             linear_UniProtQ86SQ0#PHLDB2OID31167                5
# 26              linear_UniProtQ3B7J2#GFOD2OID21216                5
# 34  linear_UniProtQ8WTQ1#DEFB104A_DEFB104BOID30849                5
# 12                linear_UniProtP05112#IL4OID20426                5
# ..                                             ...              ...
# 40              linear_UniProtQ9NRD8#DUOX2OID20059                1
# 52              linear_UniProtP23435#CBLN1OID30851                1
# 51               linear_UniProtP20809#IL11OID20455                1
# 49               linear_UniProtP13236#CCL4OID20695                1
# 76              linear_UniProtQ96PD4#IL17FOID20456                1
#
#                         Missing_Splits
# 19                                None
# 30                                None
# 26                                None
# 34                                None
# 12                                None
# ..                                 ...
# 40  Split 2, Split 3, Split 4, Split 5
# 52  Split 1, Split 3, Split 4, Split 5
# 51  Split 1, Split 3, Split 4, Split 5
# 49  Split 1, Split 3, Split 4, Split 5
# 76  Split 1, Split 2, Split 3, Split 4
#
# [77 rows x 3 columns]
